# %% [markdown]
# # In this notebook you can run different scripts that will:
#
# #### (1) Load the neccesary data to produce HNL in air showers (and plot some its ingredients).
#
# #### (2) Compute the flux of HNL for a fixed mass but different lifetimes, as well as compute the expected number of events in the Super-Kamiokande experiment.
#
# #### (3) Perform a simple statistical test to find the region of parameter space (in the $Br$ - $c\tau$ plane) that can be excluded in this search.

# %% [markdown]
#  Here we will consider the production of HNL from two mesons that are copiously produced in Air Shower: Pions and Kaons

# %%
# %matplotlib inline
from Mesons import *
# Out:
# Mesons.py called
#
# cosine values:  [-0.9 -0.7 -0.5 -0.3 -0.1  0.1  0.3  0.5  0.7  0.9]
#
# Fluxes of mesons are stored with an index idc for each cosine value, and are given as functions of the slant depth X and the energy E. The fluxes of Pi+,Pi-,K+,K- are:
#
# func_Pip[idc](X,E),func_Pim[idc](X,E),func_Kp[idc](X,E),func_Km[idc](X,E)
#
# Energy grid stored in E_vec
#
# Original data extracted from MCEq software: https://mceq.readthedocs.io/en/latest/
#
# Plotting Meson flux...

# %% [markdown]
# You can now run the hole computation of the number of events, but you must notice this will take a bit.
#
# Below the script will perform the evaluation of the number of events only for a few values of the lifetime:

# %%
from Evt_Runner import *
# Out:
# Functions.py called
#
# Evt_Runner.py called
#
# IMPORTANT NOTE: This version of the code is very slow and can be easily optimized, nevertheless it is used since it is good for test/debugging purpose.
#
# production of HNL will be computed for a mass of:
# 0.1  GeV
#
# ctau values spanned:
# [1.e-04 1.e+05]  km
#
# Integration in X started:
# iteration and ctau :  0 0.0001
# iteration and ctau :  1 100000.0
# Integration in Ep started:
# iteration and ctau :  0 0.0001
# iteration and ctau :  1 100000.0
# Calculation of number of events started:
#
# File: Events_SK.csv saved succesfully!
#
#         EvtKaon       EvtPion    ctau  cosine
# 0  0.000000e+00  0.000000e+00  0.0001    -0.7
# 1  0.000000e+00  0.000000e+00  0.0001    -0.5
# 2  0.000000e+00  0.000000e+00  0.0001    -0.3
# 3  0.000000e+00  0.000000e+00  0.0001    -0.1
# 4  2.671718e-65  3.766848e-64  0.0001     0.1

# %% [markdown]
# Run the cell below to perform a $\chi^2$ statistical test to find the excluded $Br-c\tau$ region at 90% C.L.
#
# Notice that the plot is generated for a large grid of lifetime values!

# %%
# %matplotlib inline
from Stat_test import *
# Out:
# Stat_test.py called
#
# Total number of measured events (for an arrival direction with increasing cosine angle and bin size equal to 0.2) in SK data sample :
# [380.84, 406.96, 504.95, 662.91, 662.03, 493.78, 408.05, 344.17, 290.98]
#
# Total number of background events for this search :
# [385.16, 444.59, 537.51, 629.09, 622.18, 523.36, 417.34, 348.33, 291.12]
#
# Data has been extracted from https://arxiv.org/abs/1710.09126
#
#
# chi2 test data saved !
#
# min and max chi2 value found:
# 11.589452570610085 816779053.1156772
#
# Plotting Excluded Region...
# Part of this code was used in https://arxiv.org/abs/1911.09129
