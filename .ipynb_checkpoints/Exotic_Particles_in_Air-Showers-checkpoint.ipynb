# %%
# %matplotlib inline
from Mesons import *
# Out:
# cosine values:  [-0.9 -0.7 -0.5 -0.3 -0.1  0.1  0.3  0.5  0.7  0.9]
#
# Fluxes of mesons are stored with an index idc for each cosine value, and are given as functions of the slant depth X and the energy E. The fluxes of Pi+,Pi-,K+,K- are:
#
# func_Pip[idc](X,E),func_Pim[idc](X,E),func_Kp[idc](X,E),func_Km[idc](X,E)
#
# Energy grid stored in E_vec
#
# Original data extracted from MCEq software: https://mceq.readthedocs.io/en/latest/

# %%
# If you want to explore this data you can create a data frame with the meson fluxes

df=pd.DataFrame.from_dict({'Pion (1/GeV/cm2/s/sr)':flux_Pip, 'Kaon (1/GeV/cm2/s/sr)':flux_Kp,'Energy (GeV)':E_d,'Cosine':COSINE ,'H (km)':h_d,'X (gr/cm2)':X_d,'Rho (gr/cm3)':rho_d })
df.head()
# Out:
#    Pion (1/GeV/cm2/s/sr)  Kaon (1/GeV/cm2/s/sr)  Energy (GeV)  Cosine  H (km)  \
# 0           7.828180e-07           0.000000e+00      1.166761    -0.9     1.0
# 1           4.806618e-07           0.000000e+00      1.555900    -0.9     1.0
# 2           3.072356e-07           3.715243e-09      2.074827    -0.9     1.0
# 3           2.165945e-07           3.396982e-09      2.766826    -0.9     1.0
# 4           1.432137e-07           2.452732e-09      3.689621    -0.9     1.0
#
#     X (gr/cm2)  Rho (gr/cm3)
# 0  1038.603762      0.001116
# 1  1038.603762      0.001116
# 2  1038.603762      0.001116
# 3  1038.603762      0.001116
# 4  1038.603762      0.001116

# %%
# If you want to run the hole computation of the number of events then uncomment the line below
# Take into account that this will take about 3 hrs !  
from Evt_Runner import *
# Out:
# Integration in X started:
# iteration and ctau :  0 1e-05
# iteration and ctau :  1 100000.0
# Integration in Ep started:
# 0
# 1
# Calculation of number of events started:
# File: Events_SK.csv saved succesfully!

# %%
# Here we will just load the result saved in 'Events_SK.csv'
df_ev=pd.read_csv('results/Events_SK.csv' )
df_ev
# Out:
#            EvtKaon       EvtPion          ctau  cosine
# 0         0.000000  0.000000e+00       0.00001    -0.7
# 1         0.000000  0.000000e+00       0.00001    -0.5
# 2         0.000000  0.000000e+00       0.00001    -0.3
# 3         0.000000  0.000000e+00       0.00001    -0.1
# 4         0.000000  0.000000e+00       0.00001     0.1
# ..             ...           ...           ...     ...
# 445  259610.069012  7.833604e+06  100000.00000     0.1
# 446  258875.466370  7.797460e+06  100000.00000     0.3
# 447  256467.591370  7.697569e+06  100000.00000     0.5
# 448  252361.798205  7.548131e+06  100000.00000     0.7
# 449  243062.835305  7.244558e+06  100000.00000     0.9
#
# [450 rows x 4 columns]

# %%
# Finally let us perform a chi2 statistical test to find the excluded Br-ctau region at 90% C.L. 

# %matplotlib inline
from Stat_test import *
# Out:
# Total number of measured events (for an arrival direction with increasing cosine angle and bin size equal to 0.2) in SK data sample :
# [380.84, 406.96, 504.95, 662.91, 662.03, 493.78, 408.05, 344.17, 290.98]
#
# Total number of background events for this search :
# [385.16, 444.59, 537.51, 629.09, 622.18, 523.36, 417.34, 348.33, 291.12]
#
# Data has been extracted from arXiv:1710.09126v2
#
# The relevant functions of this script are : ctau_lab_func(ctau_rest,m,E) and Seff_SK(cosine,ctau)
# Use ctau in [km]
# Seff_SK returns a value in [cm2]
#
# chi2 values saved !
#
# min and max chi2 value found:
# 11.589452570610085 816779053.1156772

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

lista1=[1,2,3]
lista2=[4,5,6]

plt.plot(lista1,lista2)
plt.show()

# %%
plt.plot(lista1,lista2,color='darkred')
plt.plot(lista2,lista1,color='darkgreen')
